# %% [markdown]
# # Exercise 1
#
# ![Exercise 1a](ex01a.png)
# ![Exercise 1b](ex01b.png)
# ![Exercise 1c](ex01c.png)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from math import *
from scipy.signal import *

# %%
alpha = 0.8414
Q = 1.3050
f0 = 100 # Hertz
w0 = 2*pi*f0
num = [1]
den = [1/(alpha*w0)**2, 1/(alpha*Q*w0), 1]
filter = lti(num, den)
filter
# Out:
# TransferFunctionContinuous(
# array([279489.02077539]),
# array([1.00000000e+00, 4.05108975e+02, 2.79489021e+05]),
# dt: None
# )

# %%
fig, ax = plt.subplots(1,1)
Time, Impulseresp = filter.impulse()
ax.plot(Time, Impulseresp)
ax.set_xlabel('time [s]')
ax.set_ylabel('amplitude')
ax.set_title('impulse response')
ax.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ---
# # Exercise 2
#
# ![Exercise 2](ex02.png)

# %%
fig, ax = plt.subplots(1,1)
Omega, Freqresp, Phase = filter.bode()
ax.semilogx(Omega/(2*pi), Freqresp)
ax.set_xlabel('frequency [hertz]')
ax.set_ylabel('gain [dB]')
ax.set_title('frequency response')
ax.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ---
# # Exercise 3
#
# ![Exercise 3](ex03.png)

# %%
fig, ax = plt.subplots(1,1)
Time, Stepresp = filter.step()
ax.plot(Time, Stepresp)
ax.set_xlabel('time [s]')
ax.set_ylabel('amplitude')
ax.set_title('step response')
ax.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ---
